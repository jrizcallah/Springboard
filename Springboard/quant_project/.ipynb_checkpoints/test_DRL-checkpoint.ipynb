# %% [markdown]
# # In this Notebook, I am going to test a Deep Reinforcement Learning Strategy

# %%
from preprocessing import preprocessors
from model import models

## This file contains functions to build the actual models

# common libraries
import pandas as pd 
import numpy as np
import time
import gym

import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')

# stable_baselines RL stuff
from stable_baselines import GAIL, SAC
from stable_baselines import ACER
from stable_baselines import PPO2
from stable_baselines import A2C
from stable_baselines import DDPG
from stable_baselines import TD3

from stable_baselines.ddpg.policies import DDPGPolicy
from stable_baselines.common.policies import MlpPolicy, MlpLstmPolicy, MlpLnLstmPolicy
from stable_baselines.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise, AdaptiveParamNoiseSpec
from stable_baselines.common.vec_env import DummyVecEnv


# Custom Functions
from preprocessing.preprocessors import *
from config import config

# Custom Environments
from env.EnvMultipleAssets_train import AssetEnvTrain
from env.EnvMultipleAssets_validation import AssetEnvValidation
from env.EnvMultipleAssets_trade import AssetEnvTrade
# Out:
# NOTICE: The environment variable DATA_BASE_URL was not specified. The default value is 'https://data-api.quantiacs.io/'
# NOTICE: The environment variable CACHE_RETENTION was not specified. The default value is '7'
# NOTICE: The environment variable CACHE_DIR was not specified. The default value is 'data-cache'
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
data = preprocessors.preprocess_data()

# %%
data = preprocessors.add_turbulence(data)

# %%
# train through 2015, then validate, then test from 2018 on
unique_trade_date = data[(data['date'] > "2009-01-01")&(data['date'] <= "2020-12-01")].date.unique()

# rebalance_window is the number of months to retrain the model
# validation_window is the number of months to validate the models 
# and select for trading
rebalance_window = 63
validation_window = 63

# %%
models.run_ensemble_strategy(df = data, 
                             unique_trade_date = unique_trade_date, 
                             rebalance_window = rebalance_window, 
                             validation_window = validation_window)
# Out:
#  = = = = = = START ENSEMBLE STRATEGY = = = = = =
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2009-09-15T00:00:00.000000000
#  = = = A2C Training = = =
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# Training Time (A2C):  38.09592382907867  Minutes
#  = = = A2C Validation from  2009-09-16T00:00:00.000000000  to  2009-12-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  606.7801343626504
#  = = = PPO Training = = =
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\ppo2\ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\ppo2\ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Training Time (PPO):  126.28192032972972  Minutes
#  = = = PPO Validation from  2009-09-16T00:00:00.000000000  to  2009-12-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  729.0341983442922
#  = = = DDPG Training = = =
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\ddpg\policies.py:136: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\ddpg\ddpg.py:94: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\ddpg\ddpg.py:444: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\johnr\anaconda3\envs\qntdev2\lib\site-packages\stable_baselines\common\tf_util.py:432: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# Training Time (DDPG):  12.94558763106664  Minutes
#  = = = DDPG Validation from  2009-09-16T00:00:00.000000000  to  2009-12-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  55.024421476109985
#  = = = = = = Trading From:  2009-12-11T00:00:00.000000000  to  2010-03-31T00:00:00.000000000  = = = = = =
# previous_total_asset:1000000
# end_total_asset:962438.0133301169
# total_reward:-37561.98666988313
# total_cost:30790.11738652277
# total_trades:2903
# Sharpe Ratio: -0.15225071354327133
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2009-12-11T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.0186935385068256  Minutes
#  = = = A2C Validation from  2009-12-14T00:00:00.000000000  to  2010-03-31T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  688.4217638782654
#  = = = PPO Training = = =
# Training Time (PPO):  6.918830374876658  Minutes
#  = = = PPO Validation from  2009-12-14T00:00:00.000000000  to  2010-03-31T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  611.5871045291868
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.1413066705067954  Minutes
#  = = = DDPG Validation from  2009-12-14T00:00:00.000000000  to  2010-03-31T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  1329.0318319226956
#  = = = = = = Trading From:  2010-03-31T00:00:00.000000000  to  2010-06-28T00:00:00.000000000  = = = = = =
# previous_total_asset:962438.0133301169
# end_total_asset:995674.9039286069
# total_reward:33236.89059849002
# total_cost:2591.5021028908814
# total_trades:2647
# Sharpe Ratio: 0.1066714088768683
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2010-03-31T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.7219140966733297  Minutes
#  = = = A2C Validation from  2010-04-01T00:00:00.000000000  to  2010-06-28T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  589.513533835988
#  = = = PPO Training = = =
# Training Time (PPO):  5.869140005111694  Minutes
#  = = = PPO Validation from  2010-04-01T00:00:00.000000000  to  2010-06-28T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  558.8623734500837
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.0564433217048645  Minutes
#  = = = DDPG Validation from  2010-04-01T00:00:00.000000000  to  2010-06-28T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  89.51450899884496
#  = = = = = = Trading From:  2010-06-28T00:00:00.000000000  to  2010-09-23T00:00:00.000000000  = = = = = =
# previous_total_asset:995674.9039286069
# end_total_asset:1066018.3136005062
# total_reward:70343.40967189928
# total_cost:4790.7288651971485
# total_trades:2647
# Sharpe Ratio: 0.31164629009262146
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2010-06-28T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.6502679427464804  Minutes
#  = = = A2C Validation from  2010-06-29T00:00:00.000000000  to  2010-09-23T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  829.376732350805
#  = = = PPO Training = = =
# Training Time (PPO):  5.594485723972321  Minutes
#  = = = PPO Validation from  2010-06-29T00:00:00.000000000  to  2010-09-23T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  684.7540790688162
#  = = = DDPG Training = = =
# Training Time (DDPG):  0.998491660753886  Minutes
#  = = = DDPG Validation from  2010-06-29T00:00:00.000000000  to  2010-09-23T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  170.79471542925722
#  = = = = = = Trading From:  2010-09-23T00:00:00.000000000  to  2010-12-21T00:00:00.000000000  = = = = = =
# previous_total_asset:1066018.3136005062
# end_total_asset:1178400.5199613187
# total_reward:112382.20636081253
# total_cost:1852.2048048373576
# total_trades:2615
# Sharpe Ratio: 0.42665039132009286
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2010-09-23T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.6255474170049031  Minutes
#  = = = A2C Validation from  2010-09-24T00:00:00.000000000  to  2010-12-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1190.7142988120977
#  = = = PPO Training = = =
# Training Time (PPO):  5.44487369855245  Minutes
#  = = = PPO Validation from  2010-09-24T00:00:00.000000000  to  2010-12-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  988.4868277537724
#  = = = DDPG Training = = =
# Training Time (DDPG):  0.9880197087923686  Minutes
#  = = = DDPG Validation from  2010-09-24T00:00:00.000000000  to  2010-12-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  593.3862496627765
#  = = = = = = Trading From:  2010-12-21T00:00:00.000000000  to  2011-03-18T00:00:00.000000000  = = = = = =
# previous_total_asset:1178400.5199613187
# end_total_asset:1281995.4459038926
# total_reward:103594.92594257393
# total_cost:2518.5621867067875
# total_trades:2819
# Sharpe Ratio: 0.3446720122172028
#  = = = = = = = = = = = = =
# turbulence_threshold:  237.18349954346598
#  = = = = = = Model Training From: 2009-01-01 to  2010-12-21T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.6205879211425782  Minutes
#  = = = A2C Validation from  2010-12-22T00:00:00.000000000  to  2011-03-18T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  513.9381778242353
#  = = = PPO Training = = =
# Training Time (PPO):  5.4833888212839765  Minutes
#  = = = PPO Validation from  2010-12-22T00:00:00.000000000  to  2011-03-18T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  429.247024114289
#  = = = DDPG Training = = =
# Training Time (DDPG):  0.9758118232091267  Minutes
#  = = = DDPG Validation from  2010-12-22T00:00:00.000000000  to  2011-03-18T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  -3.4702985767891814
#  = = = = = = Trading From:  2011-03-18T00:00:00.000000000  to  2011-06-16T00:00:00.000000000  = = = = = =
# previous_total_asset:1281995.4459038926
# end_total_asset:1289133.7324715867
# total_reward:7138.286567694042
# total_cost:20024.130337069855
# total_trades:2138
# Sharpe Ratio: 0.03250214262997981
#  = = = = = = = = = = = = =
# turbulence_threshold:  237.18349954346598
#  = = = = = = Model Training From: 2009-01-01 to  2011-03-18T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.580788000424703  Minutes
#  = = = A2C Validation from  2011-03-21T00:00:00.000000000  to  2011-06-16T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  513.8103434833737
#  = = = PPO Training = = =
# Training Time (PPO):  5.449227933088938  Minutes
#  = = = PPO Validation from  2011-03-21T00:00:00.000000000  to  2011-06-16T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  745.5448820281578
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.0029089212417603  Minutes
#  = = = DDPG Validation from  2011-03-21T00:00:00.000000000  to  2011-06-16T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  -61.937992889879055
#  = = = = = = Trading From:  2011-06-16T00:00:00.000000000  to  2011-09-13T00:00:00.000000000  = = = = = =
# previous_total_asset:1289133.7324715867
# end_total_asset:1208670.4023714208
# total_reward:-80463.33010016591
# total_cost:15084.055939196285
# total_trades:1921
# Sharpe Ratio: -0.23976341476443502
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2011-06-16T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.6070501367251078  Minutes
#  = = = A2C Validation from  2011-06-17T00:00:00.000000000  to  2011-09-13T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  608.9655944358809
#  = = = PPO Training = = =
# Training Time (PPO):  5.418247536818186  Minutes
#  = = = PPO Validation from  2011-06-17T00:00:00.000000000  to  2011-09-13T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  607.0539938712207
#  = = = DDPG Training = = =
# Training Time (DDPG):  0.9973728020985921  Minutes
#  = = = DDPG Validation from  2011-06-17T00:00:00.000000000  to  2011-09-13T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  945.8127941210489
#  = = = = = = Trading From:  2011-09-13T00:00:00.000000000  to  2011-12-09T00:00:00.000000000  = = = = = =
# previous_total_asset:1208670.4023714208
# end_total_asset:1247959.6649487007
# total_reward:39289.26257727994
# total_cost:4533.887310883148
# total_trades:2209
# Sharpe Ratio: 0.09568170611801016
#  = = = = = = = = = = = = =
# turbulence_threshold:  237.18349954346598
#  = = = = = = Model Training From: 2009-01-01 to  2011-09-13T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.6197820742925009  Minutes
#  = = = A2C Validation from  2011-09-14T00:00:00.000000000  to  2011-12-09T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  739.3826897791447
#  = = = PPO Training = = =
# Training Time (PPO):  5.419754350185395  Minutes
#  = = = PPO Validation from  2011-09-14T00:00:00.000000000  to  2011-12-09T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  687.7240725426659
#  = = = DDPG Training = = =
# Training Time (DDPG):  0.9913146376609803  Minutes
#  = = = DDPG Validation from  2011-09-14T00:00:00.000000000  to  2011-12-09T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  1.0273907846160586
#  = = = = = = Trading From:  2011-12-09T00:00:00.000000000  to  2012-03-07T00:00:00.000000000  = = = = = =
# previous_total_asset:1247959.6649487007
# end_total_asset:1381318.8311403156
# total_reward:133359.16619161493
# total_cost:7206.915659190666
# total_trades:2567
# Sharpe Ratio: 0.33835535551521373
#  = = = = = = = = = = = = =
# turbulence_threshold:  237.18349954346598
#  = = = = = = Model Training From: 2009-01-01 to  2011-12-09T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.6532041470209757  Minutes
#  = = = A2C Validation from  2011-12-12T00:00:00.000000000  to  2012-03-07T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  695.6562396421593
#  = = = PPO Training = = =
# Training Time (PPO):  5.491612406571706  Minutes
#  = = = PPO Validation from  2011-12-12T00:00:00.000000000  to  2012-03-07T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1516.6286656044183
#  = = = DDPG Training = = =
# Training Time (DDPG):  0.9919365684191386  Minutes
#  = = = DDPG Validation from  2011-12-12T00:00:00.000000000  to  2012-03-07T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  189.23973047674664
#  = = = = = = Trading From:  2012-03-07T00:00:00.000000000  to  2012-06-04T00:00:00.000000000  = = = = = =
# previous_total_asset:1381318.8311403156
# end_total_asset:1294929.728630841
# total_reward:-86389.10250947461
# total_cost:11259.418251903424
# total_trades:2829
# Sharpe Ratio: -0.2543142234024147
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2012-03-07T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.657224178314209  Minutes
#  = = = A2C Validation from  2012-03-08T00:00:00.000000000  to  2012-06-04T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  605.0293208740017
#  = = = PPO Training = = =
# Training Time (PPO):  5.61681870619456  Minutes
#  = = = PPO Validation from  2012-03-08T00:00:00.000000000  to  2012-06-04T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  866.101814572055
#  = = = DDPG Training = = =
# Training Time (DDPG):  0.9946399807929993  Minutes
#  = = = DDPG Validation from  2012-03-08T00:00:00.000000000  to  2012-06-04T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  799.1797925135763
#  = = = = = = Trading From:  2012-06-04T00:00:00.000000000  to  2012-08-30T00:00:00.000000000  = = = = = =
# previous_total_asset:1294929.728630841
# end_total_asset:1431299.0926941412
# total_reward:136369.3640633002
# total_cost:5423.03130810162
# total_trades:3119
# Sharpe Ratio: 0.3670779499709642
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2012-06-04T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.6648352106412252  Minutes
#  = = = A2C Validation from  2012-06-05T00:00:00.000000000  to  2012-08-30T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  703.2448472442627
#  = = = PPO Training = = =
# Training Time (PPO):  5.637077097098032  Minutes
#  = = = PPO Validation from  2012-06-05T00:00:00.000000000  to  2012-08-30T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  733.132375827197
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.0089072585105896  Minutes
#  = = = DDPG Validation from  2012-06-05T00:00:00.000000000  to  2012-08-30T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  389.96815693097847
#  = = = = = = Trading From:  2012-08-30T00:00:00.000000000  to  2012-11-27T00:00:00.000000000  = = = = = =
# previous_total_asset:1431299.0926941412
# end_total_asset:1346172.1928347286
# total_reward:-85126.89985941257
# total_cost:3471.628501867682
# total_trades:2755
# Sharpe Ratio: -0.2645865097157343
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2012-08-30T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.7311478018760682  Minutes
#  = = = A2C Validation from  2012-08-31T00:00:00.000000000  to  2012-11-27T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  860.5369165828728
#  = = = PPO Training = = =
# Training Time (PPO):  5.833284529050191  Minutes
#  = = = PPO Validation from  2012-08-31T00:00:00.000000000  to  2012-11-27T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  770.7781992815101
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.0367000222206115  Minutes
#  = = = DDPG Validation from  2012-08-31T00:00:00.000000000  to  2012-11-27T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  628.21595648938
#  = = = = = = Trading From:  2012-11-27T00:00:00.000000000  to  2013-02-26T00:00:00.000000000  = = = = = =
# previous_total_asset:1346172.1928347286
# end_total_asset:1385839.6032154544
# total_reward:39667.41038072575
# total_cost:4459.277951049763
# total_trades:2711
# Sharpe Ratio: 0.17792555517989814
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2012-11-27T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.7097486813863119  Minutes
#  = = = A2C Validation from  2012-11-28T00:00:00.000000000  to  2013-02-26T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  857.0382624230775
#  = = = PPO Training = = =
# Training Time (PPO):  5.845002273718516  Minutes
#  = = = PPO Validation from  2012-11-28T00:00:00.000000000  to  2013-02-26T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  647.2394976177244
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.031536372502645  Minutes
#  = = = DDPG Validation from  2012-11-28T00:00:00.000000000  to  2013-02-26T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  834.6136434718551
#  = = = = = = Trading From:  2013-02-26T00:00:00.000000000  to  2013-05-24T00:00:00.000000000  = = = = = =
# previous_total_asset:1385839.6032154544
# end_total_asset:1432589.8797217854
# total_reward:46750.27650633105
# total_cost:7906.367783811928
# total_trades:2736
# Sharpe Ratio: 0.20006156721905077
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2013-02-26T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.015476961930593  Minutes
#  = = = A2C Validation from  2013-02-27T00:00:00.000000000  to  2013-05-24T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  983.4670892432961
#  = = = PPO Training = = =
# Training Time (PPO):  6.675838220119476  Minutes
#  = = = PPO Validation from  2013-02-27T00:00:00.000000000  to  2013-05-24T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  602.0255966677012
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.1203271627426148  Minutes
#  = = = DDPG Validation from  2013-02-27T00:00:00.000000000  to  2013-05-24T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  251.62890014860554
#  = = = = = = Trading From:  2013-05-24T00:00:00.000000000  to  2013-08-21T00:00:00.000000000  = = = = = =
# previous_total_asset:1432589.8797217854
# end_total_asset:1373778.2253562468
# total_reward:-58811.65436553862
# total_cost:10914.11067648378
# total_trades:3254
# Sharpe Ratio: -0.21307081679512885
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2013-05-24T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  1.9903846065203348  Minutes
#  = = = A2C Validation from  2013-05-27T00:00:00.000000000  to  2013-08-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  914.2209303691254
#  = = = PPO Training = = =
# Training Time (PPO):  6.724550918738047  Minutes
#  = = = PPO Validation from  2013-05-27T00:00:00.000000000  to  2013-08-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1130.595853362976
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.110668941338857  Minutes
#  = = = DDPG Validation from  2013-05-27T00:00:00.000000000  to  2013-08-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  -50.34828579156499
#  = = = = = = Trading From:  2013-08-21T00:00:00.000000000  to  2013-11-18T00:00:00.000000000  = = = = = =
# previous_total_asset:1373778.2253562468
# end_total_asset:1500623.6008989534
# total_reward:126845.37554270658
# total_cost:2881.8571150761604
# total_trades:2781
# Sharpe Ratio: 0.3631256550218309
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2013-08-21T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.0217588186264037  Minutes
#  = = = A2C Validation from  2013-08-22T00:00:00.000000000  to  2013-11-18T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  822.3924241442952
#  = = = PPO Training = = =
# Training Time (PPO):  6.886495983600616  Minutes
#  = = = PPO Validation from  2013-08-22T00:00:00.000000000  to  2013-11-18T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1296.5536166117156
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.161222791671753  Minutes
#  = = = DDPG Validation from  2013-08-22T00:00:00.000000000  to  2013-11-18T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  134.86858033811475
#  = = = = = = Trading From:  2013-11-18T00:00:00.000000000  to  2014-02-14T00:00:00.000000000  = = = = = =
# previous_total_asset:1500623.6008989534
# end_total_asset:1548552.5382293668
# total_reward:47928.93733041338
# total_cost:8102.140124487814
# total_trades:2778
# Sharpe Ratio: 0.19823363827817136
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2013-11-18T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.028955825169881  Minutes
#  = = = A2C Validation from  2013-11-19T00:00:00.000000000  to  2014-02-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1292.3427320655328
#  = = = PPO Training = = =
# Training Time (PPO):  6.78831148147583  Minutes
#  = = = PPO Validation from  2013-11-19T00:00:00.000000000  to  2014-02-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  790.985285383242
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.128643004099528  Minutes
#  = = = DDPG Validation from  2013-11-19T00:00:00.000000000  to  2014-02-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  1072.0638801035418
#  = = = = = = Trading From:  2014-02-14T00:00:00.000000000  to  2014-05-14T00:00:00.000000000  = = = = = =
# previous_total_asset:1548552.5382293668
# end_total_asset:1763281.9848796912
# total_reward:214729.4466503244
# total_cost:3496.7363661757486
# total_trades:2387
# Sharpe Ratio: 0.769183182441301
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2014-02-14T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.053234839439392  Minutes
#  = = = A2C Validation from  2014-02-17T00:00:00.000000000  to  2014-05-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  972.0233040727364
#  = = = PPO Training = = =
# Training Time (PPO):  6.866919966538747  Minutes
#  = = = PPO Validation from  2014-02-17T00:00:00.000000000  to  2014-05-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  762.8071770504022
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.1333315014839171  Minutes
#  = = = DDPG Validation from  2014-02-17T00:00:00.000000000  to  2014-05-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  -14.429345974143
#  = = = = = = Trading From:  2014-05-14T00:00:00.000000000  to  2014-08-11T00:00:00.000000000  = = = = = =
# previous_total_asset:1763281.9848796912
# end_total_asset:1688173.6167594153
# total_reward:-75108.3681202759
# total_cost:6702.557118446542
# total_trades:2557
# Sharpe Ratio: -0.2884914821331068
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2014-05-14T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.080798451105754  Minutes
#  = = = A2C Validation from  2014-05-15T00:00:00.000000000  to  2014-08-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  345.3928751493953
#  = = = PPO Training = = =
# Training Time (PPO):  7.039635670185089  Minutes
#  = = = PPO Validation from  2014-05-15T00:00:00.000000000  to  2014-08-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  847.6817858307321
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.1597256501515707  Minutes
#  = = = DDPG Validation from  2014-05-15T00:00:00.000000000  to  2014-08-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  650.7020081054512
#  = = = = = = Trading From:  2014-08-11T00:00:00.000000000  to  2014-11-06T00:00:00.000000000  = = = = = =
# previous_total_asset:1688173.6167594153
# end_total_asset:1683247.0868510972
# total_reward:-4926.529908318073
# total_cost:6189.647335680585
# total_trades:2745
# Sharpe Ratio: -0.011103962027982073
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2014-08-11T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.119429604212443  Minutes
#  = = = A2C Validation from  2014-08-12T00:00:00.000000000  to  2014-11-06T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  816.0590844050405
#  = = = PPO Training = = =
# Training Time (PPO):  7.148594041665395  Minutes
#  = = = PPO Validation from  2014-08-12T00:00:00.000000000  to  2014-11-06T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  939.2060232589041
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.143887174129486  Minutes
#  = = = DDPG Validation from  2014-08-12T00:00:00.000000000  to  2014-11-06T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  534.5596794691902
#  = = = = = = Trading From:  2014-11-06T00:00:00.000000000  to  2015-02-04T00:00:00.000000000  = = = = = =
# previous_total_asset:1683247.0868510972
# end_total_asset:1715579.6847663478
# total_reward:32332.597915250575
# total_cost:6389.4224310303525
# total_trades:2766
# Sharpe Ratio: 0.1152288438405926
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2014-11-06T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.124728870391846  Minutes
#  = = = A2C Validation from  2014-11-07T00:00:00.000000000  to  2015-02-04T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1049.5791792232956
#  = = = PPO Training = = =
# Training Time (PPO):  7.253589069843292  Minutes
#  = = = PPO Validation from  2014-11-07T00:00:00.000000000  to  2015-02-04T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  871.3764513934505
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.1492574691772461  Minutes
#  = = = DDPG Validation from  2014-11-07T00:00:00.000000000  to  2015-02-04T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  95.70512576679755
#  = = = = = = Trading From:  2015-02-04T00:00:00.000000000  to  2015-05-04T00:00:00.000000000  = = = = = =
# previous_total_asset:1715579.6847663478
# end_total_asset:1631828.530822643
# total_reward:-83751.15394370467
# total_cost:1802.6072228938096
# total_trades:2594
# Sharpe Ratio: -0.3070004308734828
#  = = = = = = = = = = = = =
# turbulence_threshold:  237.18349954346598
#  = = = = = = Model Training From: 2009-01-01 to  2015-02-04T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.124670060475667  Minutes
#  = = = A2C Validation from  2015-02-05T00:00:00.000000000  to  2015-05-04T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  809.266746228804
#  = = = PPO Training = = =
# Training Time (PPO):  7.223507746060689  Minutes
#  = = = PPO Validation from  2015-02-05T00:00:00.000000000  to  2015-05-04T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  883.4468611147942
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.187204082806905  Minutes
#  = = = DDPG Validation from  2015-02-05T00:00:00.000000000  to  2015-05-04T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  191.2622153760418
#  = = = = = = Trading From:  2015-05-04T00:00:00.000000000  to  2015-07-30T00:00:00.000000000  = = = = = =
# previous_total_asset:1631828.530822643
# end_total_asset:1615520.0814208605
# total_reward:-16308.449401782593
# total_cost:3217.228035349372
# total_trades:2898
# Sharpe Ratio: -0.03886207740703793
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2015-05-04T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.1450418631235757  Minutes
#  = = = A2C Validation from  2015-05-05T00:00:00.000000000  to  2015-07-30T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1030.261200734209
#  = = = PPO Training = = =
# Training Time (PPO):  7.35582803885142  Minutes
#  = = = PPO Validation from  2015-05-05T00:00:00.000000000  to  2015-07-30T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1169.3987581198655
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.2037911295890809  Minutes
#  = = = DDPG Validation from  2015-05-05T00:00:00.000000000  to  2015-07-30T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  750.3493123188151
#  = = = = = = Trading From:  2015-07-30T00:00:00.000000000  to  2015-10-27T00:00:00.000000000  = = = = = =
# previous_total_asset:1615520.0814208605
# end_total_asset:1589674.8239626852
# total_reward:-25845.2574581753
# total_cost:4936.932687620862
# total_trades:2809
# Sharpe Ratio: -0.06118117086996904
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2015-07-30T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.2137741327285765  Minutes
#  = = = A2C Validation from  2015-07-31T00:00:00.000000000  to  2015-10-27T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  957.6622731234891
#  = = = PPO Training = = =
# Training Time (PPO):  7.369467957814535  Minutes
#  = = = PPO Validation from  2015-07-31T00:00:00.000000000  to  2015-10-27T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  967.2692622141219
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.196951727072398  Minutes
#  = = = DDPG Validation from  2015-07-31T00:00:00.000000000  to  2015-10-27T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  140.92145497772344
#  = = = = = = Trading From:  2015-10-27T00:00:00.000000000  to  2016-01-25T00:00:00.000000000  = = = = = =
# previous_total_asset:1589674.8239626852
# end_total_asset:1513471.1084734674
# total_reward:-76203.71548921778
# total_cost:4608.528072126526
# total_trades:2517
# Sharpe Ratio: -0.1898564464786004
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2015-10-27T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.2239187161127725  Minutes
#  = = = A2C Validation from  2015-10-28T00:00:00.000000000  to  2016-01-25T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  914.7059104530884
#  = = = PPO Training = = =
# Training Time (PPO):  7.574435869852702  Minutes
#  = = = PPO Validation from  2015-10-28T00:00:00.000000000  to  2016-01-25T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1129.8843023756629
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.2143649101257323  Minutes
#  = = = DDPG Validation from  2015-10-28T00:00:00.000000000  to  2016-01-25T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  327.4219634291495
#  = = = = = = Trading From:  2016-01-25T00:00:00.000000000  to  2016-04-21T00:00:00.000000000  = = = = = =
# previous_total_asset:1513471.1084734674
# end_total_asset:1640962.4494905723
# total_reward:127491.34101710492
# total_cost:5954.502505039848
# total_trades:2796
# Sharpe Ratio: 0.33658899374040707
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2016-01-25T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.2243830005327863  Minutes
#  = = = A2C Validation from  2016-01-26T00:00:00.000000000  to  2016-04-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  739.299382347215
#  = = = PPO Training = = =
# Training Time (PPO):  7.509608825047811  Minutes
#  = = = PPO Validation from  2016-01-26T00:00:00.000000000  to  2016-04-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  668.3005462923286
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.2389018058776855  Minutes
#  = = = DDPG Validation from  2016-01-26T00:00:00.000000000  to  2016-04-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  78.31738678458612
#  = = = = = = Trading From:  2016-04-21T00:00:00.000000000  to  2016-07-19T00:00:00.000000000  = = = = = =
# previous_total_asset:1640962.4494905723
# end_total_asset:1690664.9430454143
# total_reward:49702.49355484196
# total_cost:4825.668469652754
# total_trades:2644
# Sharpe Ratio: 0.210909572004873
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2016-04-21T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.4928141315778096  Minutes
#  = = = A2C Validation from  2016-04-22T00:00:00.000000000  to  2016-07-19T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  560.2595234719524
#  = = = PPO Training = = =
# Training Time (PPO):  8.375908335049948  Minutes
#  = = = PPO Validation from  2016-04-22T00:00:00.000000000  to  2016-07-19T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  749.022612841726
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.2825632492701213  Minutes
#  = = = DDPG Validation from  2016-04-22T00:00:00.000000000  to  2016-07-19T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  39.89616530679105
#  = = = = = = Trading From:  2016-07-19T00:00:00.000000000  to  2016-10-14T00:00:00.000000000  = = = = = =
# previous_total_asset:1690664.9430454143
# end_total_asset:1681657.9559834877
# total_reward:-9006.98706192663
# total_cost:14233.908623388597
# total_trades:3072
# Sharpe Ratio: -0.0382948977595838
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2016-07-19T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.5179972648620605  Minutes
#  = = = A2C Validation from  2016-07-20T00:00:00.000000000  to  2016-10-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1013.3198019497696
#  = = = PPO Training = = =
# Training Time (PPO):  8.51216880083084  Minutes
#  = = = PPO Validation from  2016-07-20T00:00:00.000000000  to  2016-10-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  924.7902951382857
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.2904942671457926  Minutes
#  = = = DDPG Validation from  2016-07-20T00:00:00.000000000  to  2016-10-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  6.200077543007057
#  = = = = = = Trading From:  2016-10-14T00:00:00.000000000  to  2017-01-11T00:00:00.000000000  = = = = = =
# previous_total_asset:1681657.9559834877
# end_total_asset:1712322.204004809
# total_reward:30664.24802132137
# total_cost:1563.3037671185568
# total_trades:2544
# Sharpe Ratio: 0.23878101730000975
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2016-10-14T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.5675031105677286  Minutes
#  = = = A2C Validation from  2016-10-17T00:00:00.000000000  to  2017-01-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  627.9530761041772
#  = = = PPO Training = = =
# Training Time (PPO):  8.592780725161235  Minutes
#  = = = PPO Validation from  2016-10-17T00:00:00.000000000  to  2017-01-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  926.7095022973484
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.298476755619049  Minutes
#  = = = DDPG Validation from  2016-10-17T00:00:00.000000000  to  2017-01-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  -6.1403748082365475
#  = = = = = = Trading From:  2017-01-11T00:00:00.000000000  to  2017-04-10T00:00:00.000000000  = = = = = =
# previous_total_asset:1712322.204004809
# end_total_asset:1721897.8409661748
# total_reward:9575.636961365817
# total_cost:1136.0039643407436
# total_trades:2699
# Sharpe Ratio: 0.09888720883490115
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2017-01-11T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.548688801129659  Minutes
#  = = = A2C Validation from  2017-01-12T00:00:00.000000000  to  2017-04-10T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1311.2292261503676
#  = = = PPO Training = = =
# Training Time (PPO):  8.611754743258158  Minutes
#  = = = PPO Validation from  2017-01-12T00:00:00.000000000  to  2017-04-10T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1480.7056995878736
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3303749879201254  Minutes
#  = = = DDPG Validation from  2017-01-12T00:00:00.000000000  to  2017-04-10T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  180.57735440310444
#  = = = = = = Trading From:  2017-04-10T00:00:00.000000000  to  2017-07-06T00:00:00.000000000  = = = = = =
# previous_total_asset:1721897.8409661748
# end_total_asset:1735053.8545054886
# total_reward:13156.013539313804
# total_cost:278.3873645762912
# total_trades:2804
# Sharpe Ratio: 0.12891104557629177
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2017-04-10T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.5788703481356303  Minutes
#  = = = A2C Validation from  2017-04-11T00:00:00.000000000  to  2017-07-06T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1730.2480767295044
#  = = = PPO Training = = =
# Training Time (PPO):  8.706410539150237  Minutes
#  = = = PPO Validation from  2017-04-11T00:00:00.000000000  to  2017-07-06T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  609.0827863174496
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3030454754829406  Minutes
#  = = = DDPG Validation from  2017-04-11T00:00:00.000000000  to  2017-07-06T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  131.63713594060235
#  = = = = = = Trading From:  2017-07-06T00:00:00.000000000  to  2017-10-03T00:00:00.000000000  = = = = = =
# previous_total_asset:1735053.8545054886
# end_total_asset:1747494.8131655012
# total_reward:12440.958660012577
# total_cost:703.6009827923806
# total_trades:2700
# Sharpe Ratio: 0.12895780297643564
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2017-07-06T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.6289307435353595  Minutes
#  = = = A2C Validation from  2017-07-07T00:00:00.000000000  to  2017-10-03T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  652.1458168992212
#  = = = PPO Training = = =
# Training Time (PPO):  8.780022954940796  Minutes
#  = = = PPO Validation from  2017-07-07T00:00:00.000000000  to  2017-10-03T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  685.0085222568568
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3658547759056092  Minutes
#  = = = DDPG Validation from  2017-07-07T00:00:00.000000000  to  2017-10-03T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  416.04670089148874
#  = = = = = = Trading From:  2017-10-03T00:00:00.000000000  to  2017-12-29T00:00:00.000000000  = = = = = =
# previous_total_asset:1747494.8131655012
# end_total_asset:1784460.0132941564
# total_reward:36965.20012865518
# total_cost:4029.32328879734
# total_trades:2548
# Sharpe Ratio: 0.3934146967053421
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2017-10-03T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.6148101250330607  Minutes
#  = = = A2C Validation from  2017-10-04T00:00:00.000000000  to  2017-12-29T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  813.7392870672354
#  = = = PPO Training = = =
# Training Time (PPO):  8.768070077896118  Minutes
#  = = = PPO Validation from  2017-10-04T00:00:00.000000000  to  2017-12-29T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  859.0448752659805
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3108037948608398  Minutes
#  = = = DDPG Validation from  2017-10-04T00:00:00.000000000  to  2017-12-29T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  432.1044105881588
#  = = = = = = Trading From:  2017-12-29T00:00:00.000000000  to  2018-03-29T00:00:00.000000000  = = = = = =
# previous_total_asset:1784460.0132941564
# end_total_asset:1778296.3314098022
# total_reward:-6163.681884354213
# total_cost:3595.2235176145414
# total_trades:2841
# Sharpe Ratio: -0.02664217296547128
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2017-12-29T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.661712908744812  Minutes
#  = = = A2C Validation from  2018-01-02T00:00:00.000000000  to  2018-03-29T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  890.8266724087588
#  = = = PPO Training = = =
# Training Time (PPO):  8.839231320222218  Minutes
#  = = = PPO Validation from  2018-01-02T00:00:00.000000000  to  2018-03-29T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  787.6096078638374
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3247181932131449  Minutes
#  = = = DDPG Validation from  2018-01-02T00:00:00.000000000  to  2018-03-29T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  -40.54972747783205
#  = = = = = = Trading From:  2018-03-29T00:00:00.000000000  to  2018-06-26T00:00:00.000000000  = = = = = =
# previous_total_asset:1778296.3314098022
# end_total_asset:1795303.357438657
# total_reward:17007.026028854772
# total_cost:6225.878125143066
# total_trades:2660
# Sharpe Ratio: 0.16464513294624658
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2018-03-29T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.6534427960713702  Minutes
#  = = = A2C Validation from  2018-03-30T00:00:00.000000000  to  2018-06-26T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  650.8975289272628
#  = = = PPO Training = = =
# Training Time (PPO):  8.940478614966075  Minutes
#  = = = PPO Validation from  2018-03-30T00:00:00.000000000  to  2018-06-26T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  827.4995420557946
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.354102377096812  Minutes
#  = = = DDPG Validation from  2018-03-30T00:00:00.000000000  to  2018-06-26T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  67.47869170278403
#  = = = = = = Trading From:  2018-06-26T00:00:00.000000000  to  2018-09-21T00:00:00.000000000  = = = = = =
# previous_total_asset:1795303.357438657
# end_total_asset:1781324.7899508732
# total_reward:-13978.56748778373
# total_cost:3222.280905491984
# total_trades:2921
# Sharpe Ratio: -0.07632150077561382
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2018-06-26T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.655827224254608  Minutes
#  = = = A2C Validation from  2018-06-27T00:00:00.000000000  to  2018-09-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  670.185709428991
#  = = = PPO Training = = =
# Training Time (PPO):  9.064950875441234  Minutes
#  = = = PPO Validation from  2018-06-27T00:00:00.000000000  to  2018-09-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  638.7470280625475
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3790685415267945  Minutes
#  = = = DDPG Validation from  2018-06-27T00:00:00.000000000  to  2018-09-21T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  322.1092010652585
#  = = = = = = Trading From:  2018-09-21T00:00:00.000000000  to  2018-12-19T00:00:00.000000000  = = = = = =
# previous_total_asset:1781324.7899508732
# end_total_asset:1735078.1116707234
# total_reward:-46246.67828014982
# total_cost:1114.319131354281
# total_trades:2781
# Sharpe Ratio: -0.2330910841042321
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2018-09-21T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.6842941006024676  Minutes
#  = = = A2C Validation from  2018-09-24T00:00:00.000000000  to  2018-12-19T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1160.007736794379
#  = = = PPO Training = = =
# Training Time (PPO):  9.055918924013774  Minutes
#  = = = PPO Validation from  2018-09-24T00:00:00.000000000  to  2018-12-19T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1369.5398770120808
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3524417837460836  Minutes
#  = = = DDPG Validation from  2018-09-24T00:00:00.000000000  to  2018-12-19T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  -195.37023024769505
#  = = = = = = Trading From:  2018-12-19T00:00:00.000000000  to  2019-03-19T00:00:00.000000000  = = = = = =
# previous_total_asset:1735078.1116707234
# end_total_asset:1866006.796991343
# total_reward:130928.6853206195
# total_cost:2757.7788525736228
# total_trades:2493
# Sharpe Ratio: 0.4088873734154126
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2018-12-19T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.6866826097170513  Minutes
#  = = = A2C Validation from  2018-12-20T00:00:00.000000000  to  2019-03-19T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1030.3049142587165
#  = = = PPO Training = = =
# Training Time (PPO):  9.183377782503763  Minutes
#  = = = PPO Validation from  2018-12-20T00:00:00.000000000  to  2019-03-19T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  733.2961593581608
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3693641026814778  Minutes
#  = = = DDPG Validation from  2018-12-20T00:00:00.000000000  to  2019-03-19T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  389.427590918506
#  = = = = = = Trading From:  2019-03-19T00:00:00.000000000  to  2019-06-14T00:00:00.000000000  = = = = = =
# previous_total_asset:1866006.796991343
# end_total_asset:1856250.1409265653
# total_reward:-9756.656064777635
# total_cost:2487.5492932470174
# total_trades:2788
# Sharpe Ratio: -0.01698046662617434
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2019-03-19T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.752544871966044  Minutes
#  = = = A2C Validation from  2019-03-20T00:00:00.000000000  to  2019-06-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1106.0725232215266
#  = = = PPO Training = = =
# Training Time (PPO):  9.180491105715435  Minutes
#  = = = PPO Validation from  2019-03-20T00:00:00.000000000  to  2019-06-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1329.2650203283886
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.355118719736735  Minutes
#  = = = DDPG Validation from  2019-03-20T00:00:00.000000000  to  2019-06-14T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  52.40694804298825
#  = = = = = = Trading From:  2019-06-14T00:00:00.000000000  to  2019-09-11T00:00:00.000000000  = = = = = =
# previous_total_asset:1856250.1409265653
# end_total_asset:1718831.146579012
# total_reward:-137418.99434755323
# total_cost:1223.9078802397146
# total_trades:2559
# Sharpe Ratio: -0.31929411498012744
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2019-06-14T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.7804036736488342  Minutes
#  = = = A2C Validation from  2019-06-17T00:00:00.000000000  to  2019-09-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  759.7672556701086
#  = = = PPO Training = = =
# Training Time (PPO):  9.275624505678813  Minutes
#  = = = PPO Validation from  2019-06-17T00:00:00.000000000  to  2019-09-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1504.4248034805812
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3780956387519836  Minutes
#  = = = DDPG Validation from  2019-06-17T00:00:00.000000000  to  2019-09-11T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  447.81934664134195
#  = = = = = = Trading From:  2019-09-11T00:00:00.000000000  to  2019-12-09T00:00:00.000000000  = = = = = =
# previous_total_asset:1718831.146579012
# end_total_asset:1776235.415182155
# total_reward:57404.26860314305
# total_cost:2316.2554476990026
# total_trades:2683
# Sharpe Ratio: 0.15391954214712378
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2019-09-11T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.795144673188527  Minutes
#  = = = A2C Validation from  2019-09-12T00:00:00.000000000  to  2019-12-09T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  792.2523558938725
#  = = = PPO Training = = =
# Training Time (PPO):  9.385316101710002  Minutes
#  = = = PPO Validation from  2019-09-12T00:00:00.000000000  to  2019-12-09T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  757.483149649585
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3773280739784242  Minutes
#  = = = DDPG Validation from  2019-09-12T00:00:00.000000000  to  2019-12-09T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  127.42265832189533
#  = = = = = = Trading From:  2019-12-09T00:00:00.000000000  to  2020-03-06T00:00:00.000000000  = = = = = =
# previous_total_asset:1776235.415182155
# end_total_asset:1708338.591507335
# total_reward:-67896.82367482013
# total_cost:5697.915294628801
# total_trades:2645
# Sharpe Ratio: -0.1684207999079535
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2019-12-09T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.8319560249646503  Minutes
#  = = = A2C Validation from  2019-12-10T00:00:00.000000000  to  2020-03-06T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  758.3778332872056
#  = = = PPO Training = = =
# Training Time (PPO):  9.456015714009602  Minutes
#  = = = PPO Validation from  2019-12-10T00:00:00.000000000  to  2020-03-06T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  879.789266218064
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3835790634155274  Minutes
#  = = = DDPG Validation from  2019-12-10T00:00:00.000000000  to  2020-03-06T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  132.08143609332842
#  = = = = = = Trading From:  2020-03-06T00:00:00.000000000  to  2020-06-03T00:00:00.000000000  = = = = = =
# previous_total_asset:1708338.591507335
# end_total_asset:1592166.4609527076
# total_reward:-116172.1305546274
# total_cost:2684.1951165766336
# total_trades:2879
# Sharpe Ratio: -0.13511650909900788
#  = = = = = = = = = = = = =
# turbulence_threshold:  237.18349954346598
#  = = = = = = Model Training From: 2009-01-01 to  2020-03-06T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.8977095683415732  Minutes
#  = = = A2C Validation from  2020-03-09T00:00:00.000000000  to  2020-06-03T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  564.6981013780046
#  = = = PPO Training = = =
# Training Time (PPO):  9.614441033204397  Minutes
#  = = = PPO Validation from  2020-03-09T00:00:00.000000000  to  2020-06-03T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  526.6665732839155
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.4418583710988362  Minutes
#  = = = DDPG Validation from  2020-03-09T00:00:00.000000000  to  2020-06-03T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  109.32882366358194
#  = = = = = = Trading From:  2020-06-03T00:00:00.000000000  to  2020-08-31T00:00:00.000000000  = = = = = =
# previous_total_asset:1592166.4609527076
# end_total_asset:1570880.3299535362
# total_reward:-21286.130999171408
# total_cost:18028.75587890118
# total_trades:2479
# Sharpe Ratio: -0.03374118577998979
#  = = = = = = = = = = = = =
# turbulence_threshold:  2016.0940893213701
#  = = = = = = Model Training From: 2009-01-01 to  2020-06-03T00:00:00.000000000
#  = = = A2C Training = = =
# Training Time (A2C):  2.8905099987983705  Minutes
#  = = = A2C Validation from  2020-06-04T00:00:00.000000000  to  2020-08-31T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# A2C Sharpe Ratio:  1754.146629740525
#  = = = PPO Training = = =
# Training Time (PPO):  9.697973072528839  Minutes
#  = = = PPO Validation from  2020-06-04T00:00:00.000000000  to  2020-08-31T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# PPO Sharpe Ratio:  1019.5175129256063
#  = = = DDPG Training = = =
# Training Time (DDPG):  1.3841155687967936  Minutes
#  = = = DDPG Validation from  2020-06-04T00:00:00.000000000  to  2020-08-31T00:00:00.000000000
# TERMINAL VALIDATION STATE REACHED
# DDPG Sharpe Ratio:  345.9109122408294
#  = = = = = = Trading From:  2020-08-31T00:00:00.000000000  to  2020-11-26T00:00:00.000000000  = = = = = =
# previous_total_asset:1570880.3299535362
# end_total_asset:1558610.5300513117
# total_reward:-12269.799902224448
# total_cost:5898.571510172886
# total_trades:2661
# Sharpe Ratio: -0.022260037510435635
# Ensemble Strategy Took:  656.9124318679173  Minutes

# %% [markdown]
# # Put all Trade Results Together

# %%
import os
file_list = os.listdir('results')

# %%
file_list = [file for file in file_list if ('account_value_trade' in file) & ('csv' in file)]

# %%
file_list.sort()
test = [file.split('.') for file in file_list]
test = [file[0].split('_') for file in test]
test = [file[4] for file in test]
test = [int(file) for file in test]
test
# Out:
# [1008,
#  1071,
#  1134,
#  1197,
#  126,
#  1260,
#  1323,
#  1386,
#  1449,
#  1512,
#  1575,
#  1638,
#  1701,
#  1764,
#  1827,
#  189,
#  1890,
#  1953,
#  2016,
#  2079,
#  2142,
#  2205,
#  2268,
#  2331,
#  2394,
#  2457,
#  252,
#  2520,
#  2583,
#  2646,
#  2709,
#  2772,
#  2835,
#  2898,
#  315,
#  378,
#  441,
#  504,
#  567,
#  630,
#  693,
#  756,
#  819,
#  882,
#  945]

# %%
files = pd.DataFrame({'file_name':file_list, 'file_number':test})
files = files.sort_values('file_number')

# %%
results_df = pd.DataFrame()
for file in files['file_name']:
    if 'account_value_trade' in str(file):
        if 'csv' in str(file):
            temp_df = pd.read_csv('results/' + file)
            results_df = results_df.append(temp_df)

# %%
results_df.drop(results_df.columns[0], axis=1, inplace=True)
results_df.columns = ['Portfolio_Value']

# %%
results_df = results_df.reset_index(drop=True)

# %%
plt.clf()
sns.lineplot(x=results_df.index, y=results_df[results_df.columns[0]])
plt.savefig('total_results_plot.png')
