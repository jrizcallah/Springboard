# %%
import pandas as pd

# %%
data = pd.read_csv('processed_data.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
data
# Out:
#               date asset        open        high         low       close  \
# 0       2009-09-15  F_AD      0.8562      0.8586      0.8502      0.8570
# 1       2009-09-15  F_AE    307.0000    310.1000    305.7500    308.4000
# 2       2009-09-15  F_AH    125.5000    127.5000    123.6000    126.8000
# 3       2009-09-15  F_AX   5625.0000   5651.5000   5589.0000   5622.5000
# 4       2009-09-15  F_BC     68.4800     70.0000     67.5200     69.8600
# ...            ...   ...         ...         ...         ...         ...
# 234541  2021-04-28  F_VX     19.8300     20.0000     19.5000     19.6632
# 234542  2021-04-28   F_W    733.0000    741.2500    711.5000    722.7500
# 234543  2021-04-28  F_XX   3370.0000   3377.0000   3360.0000   3371.0000
# 234544  2021-04-28  F_YM  33815.0000  33868.0000  33690.0000  33724.0000
# 234545  2021-04-28  F_ZQ     99.9200     99.9300     99.9200     99.9300
#
#           volume        macd        rsi         cci        adx  turbulence
# ...

# %%
data['close'].max()
# Out:
# 34081.0

# %%
assets = data['asset'].unique()
for asset in assets:
    temp = data[data['asset'] == asset]
    temp['cci'] = (temp['cci'] - temp['cci'].mean()) / temp['cci'].std()
    data.loc[data['asset'] == asset, 'cci'] = temp['cci']
# Out:
# <ipython-input-35-7c72aa933e1b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['cci'] = (temp['cci'] - temp['cci'].mean()) / temp['cci'].std()

# %%
data['close'].argmin()
# Out:
# 227467

# %%
import matplotlib.pyplot as plt
